# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Can not drop `NaN` or eslse not enough data available!

# %%
data = pd.read_csv('owid_data.csv').fillna(0)
data.shape
# Out:
# (21590, 129)

# %%
data['country'].nunique()
# Out:
# 294

# %%
data.groupby('country').mean()
# Out:
#                  year    population           gdp  biofuel_cons_change_pct  \
# country
# ASEAN (Ember)  2011.0  0.000000e+00  0.000000e+00                 0.000000
# Afghanistan    1960.5  1.264643e+07  1.213968e+10                 0.000000
# Africa         1961.0  4.560140e+08  0.000000e+00                 8.897553
# Africa (EI)    1993.5  0.000000e+00  0.000000e+00                18.868948
# Africa (EIA)   2000.5  0.000000e+00  0.000000e+00                 0.000000
# ...               ...           ...           ...                      ...
# World          1961.0  3.811038e+09  4.991495e+12                 4.399756
# Yemen          2001.0  1.997416e+07  6.397836e+10                 0.000000
# Yugoslavia     1945.5  1.329413e+07  6.845690e+10                 0.000000
# Zambia         1961.0  5.543610e+06  8.818052e+09                 0.000000
# Zimbabwe       1961.0  5.931366e+06  8.654644e+09                 0.000000
#
# ...
